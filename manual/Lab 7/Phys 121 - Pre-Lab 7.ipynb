# %% [markdown]
# # <div style="background-color:rgba(204, 229, 255, 0.5); text-align:center; vertical-align: middle; padding:40px 0; margin-top:30px"><span style="color:rgba(0, 76, 153, 1);">PHYS 121 Pre-Lab #7</span></div>
# # The Earth's Magnetic Field

# %% [markdown]
# ***
# ## Learning Objectives:
# * <b><span style="color:rgba(0, 153, 76, 1);"> Gain an understanding of the duality between magnetism and electricity as described by Faraday's law and Ampère's law.  </span></b>
# * <b><span style="color:rgba(0, 153, 76, 1);"> Use this duality to measure the horizontal component of the local magnetic field using a basic solenoid and a compass. </span></b>

# %% [markdown]
# ***
# ## Introduction:
#
# You are likely aware of the idea that the Earth has north and south magnetic poles. However, these names are a bit misleading. For one thing, since Earth's "magnetic north pole" attracts the north end of a magnet, we would actually call it a *south* pole in physics. Further, these poles don't exactly coincide with the geological poles, and in fact the north pole is wandering NNW at about 55km per year. To confuse matters even more, by taking note of how flows of ferromagnetic magma have solidified in the past, we know that the Earth's fields undergo occasional **geomagnetic reversal** events, in which the magnetic poles effectively swap places.
#
# Aside from all these complications, the magnetic field of the Earth is stable enough for us to use it for navigation. In a compass, a magnetized needle on a low-friction bearing will swivel to align itself with the local magnetic field. This tells us what *direction* the horizontal component of the local field is pointing in, but what of the *magnitude*? Where you stand, how strong is the Earth's magnetic field?
#
# In this pre-lab, you will use simple vector analysis to see how it's possible to measure the local magnetic field using only a compass, a coil of wire, and a DC power source. This will equip you with the analytic tools to carry out the actual experiment in this week's lab.
#
# Together, the power source and the coil form a simple electromagnet called a **solenoid**. In accordance with Ampère's law, the steady current produces a magnetic field. Due to the geometry of the solenoid, the internal field points along the axis of the coil (Fig. 1).
#
# Calculating the magnetic field at an arbitrary position near an arbitrary solenoid, while not impossible, is very difficult to do and the expression obtained is quite ugly. However, if we're interested in the field at the midpoint of the solenoid's axis, the calculation can be greatly simplified by assuming that the solenoid is *infinitely long*. It can be shown that this approximation holds when the radius of the solenoid is much less than its length.
#
# One obtains the following:
#
# \begin{align}
# \vec{B} = \mu_0 n I
# \label{eq:Bmag} \tag{1}
# \end{align}
#
# where $I$ is the electrical current in the coil, $n$ is the **turn density**, or the number of turns per unit length, and $ \mu_0 = 4\pi \times 10^{-7} $ H/m is a constant, called the **vacuum permeability**.
#
# <br>
# <br>
# <p>
# <center>
# <img src="solenoid.svg" alt="image info" style="width: 45%; height: auto;" /><br>
# <b>Fig. 1: The magnetic field generated by a solenoid. Near the centre of the solenoid, the magnetic field lines essentially parallel to the axis of the solenoid, but begin to bend near the ends.    Figure adapted from <a href = "https://commons.wikimedia.org/wiki/File:VFPt_Solenoid_correct3_Babs.svg">Wikimedia commons</b>.</center>
# </p>

# %% [markdown]
# **<span style="color:blue">Question 1:</span>**
#
# You place a compass in the middle of a solenoid with current $I = 0$. The solenoid is oriented with its axis perpendicular to magnetic north, so that the angle between the compass needle and the axis of the solenoid is $90^\circ$.
#
# You then turn on the power, so that the current flows through the solenoid in the same manner as Fig. 1. What happens to the needle as you gradually increase the current? Why?

# %% [markdown]
# ***
# **<span style="color:blue">Answer 1:</span>**
#
# [//]: # (Please do not delete this comment or anything above it.  Anything below this comment can be deleted.)
#
# Double click this cell and enter your text here.  When done, hit 'Shift' + 'Enter' to execute the cell.  You may delete this text when entering your answer.
# ***

# %% [markdown]
# **<span style="color:blue">Question 2:</span>**
#
# Let $\vec{B}_{Loc}$ be the local magnetic field. The observed deflection is due to the magnetic field generated by the solenoid $\vec{B}_{Sol}$. By the principle of superposition, the *total magnetic field* in the middle of the solenoid is given by
#
# $$ \vec{B}_{Tot} = \vec{B}_{Loc} + \vec{B}_{Sol} $$
#
# <br>
# <p>
# <center>
# <img src="btot.svg" style="width: 35%" />
# <b>Fig. 2: The total magnetic field is given by superposition of the fixed local field $\vec{B}_{Loc}$ and the variable solenoid field $\vec{B}_{Sol}$. The direction of this total field (and thus the measured angle $\theta$) can be changed by increasing the current through the solenoid, according to Eq. 1. </b></center>
# </p>
#
# The compass needle will point along $\vec{B}_{Tot}$. Noting that these fields are perpendicular to one another, use some simple trigonometric analysis to find an expression relating the angle $\varphi$ from Fig. 2 and the relative magnitudes of the local field and the solenoid field. Solve your expression for $B_{Loc}$ = $\left|\left| \vec{B}_{Loc} \right|\right|$.
#
# Then, type your expression in Python in the following code cell, using the variable names B_loc, B_sol, and phi.
#
# ***
# **<span style="color:blue">Answer 2:</span>**

# %%
B_loc =

# %% [markdown]
# ***
# **<span style="color:blue">Question 3:</span>**
#
# If we're thinking like experimentalists, we should be seeking an expression of the quantity of interest (the local magnetic field) in terms of easily measured quantities. The angle $\varphi$ is easy to measure, but it's not obvious how to measure $B_{Sol}$.
#
# Use Eq. 1 and your expression from question 2 to find an expression for $B_{Loc}$ in terms of the current. Type your expression in Python in the following code cell, using variable names B_loc, B_sol, phi, and n. Remember that $ \mu_0 = 4\pi \times 10^{-7} $ H/m.
#
#
# ***
# **<span style="color:blue">Answer 3:</span>**

# %%
B_loc =

# %% [markdown]
# ***
# **<span style="color:blue">Question 4:</span>**
#
# To get a better estimate of $B_{Loc}$, we should take a set of measurements of $\varphi$ over a range of currents $I$. Suppose you were to plot $\tan\varphi$ as a function of $I$. <br> <br>
# >  (a)  Find the slope $m$ of this line. You should be able to find your answer by rearranging your expression from Question 3. <br>
#   (b)  Express $B_{Loc}$ as a function of $m$.
#
# Type your expression in Python in the following code cell, using the variable m for the slope.
# ***
# **<span style="color:blue">Answer 4:</span>**

# %%
B_loc =
