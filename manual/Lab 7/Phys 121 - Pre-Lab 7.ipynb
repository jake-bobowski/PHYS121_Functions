# %% [markdown]
# # <div style="background-color:rgba(204, 229, 255, 0.5); text-align:center; vertical-align: middle; padding:40px 0; margin-top:30px"><span style="color:rgba(0, 76, 153, 1);">PHYS 121 Pre-Lab #7</span></div>
# # Earth's Magnetic Field

# %% [markdown]
# ***
# ## Learning Objectives:
# * <b><span style="color:rgba(0, 153, 76, 1);"> Gain an understanding of the duality between magnetism and electricity as described by Ampère's law and Faraday's law.  </span></b>
# * <b><span style="color:rgba(0, 153, 76, 1);"> Use this duality to measure the properties of Earth's magnetic field at our posiition on the Earth's surface. </span></b>

# %% [markdown]
# ***
# ## Introduction:
#
# You are likely aware of the idea that the Earth has north and south magnetic poles. However, these names are a bit misleading. For one thing, since Earth's geographic north attracts the north pole of a bar magnet, Earth's *geographic* north pole is  a *magnetic* south pole.  This situation is depicted in Fig. 1.
#
# <p>
# <center>
# <img src="https://cmps-people.ok.ubc.ca/jbobowsk/PHYS_121_Lab/Lab7/images/Earth-field.png" alt="image info" style="width: 45%; height: auto;" /><br>
#     <b>Fig. 1: The <i>magnetic</i> south pole of the Earth is located at its <i>geographic</i> north pole.    Figure adapted from <a href ="https://commons.wikimedia.org/wiki/File:Openstax_college-physics_22.4_earth-magnet.jpg">Wikimedia commons</b>.</center>
# </p>
#
# Further, these poles don't exactly coincide with the geological poles, and in fact the north pole is wandering NNW at about 55km per year. To confuse matters even more, by taking note of how flows of ferromagnetic magma have solidified in the past, we know that the Earth's fields undergo occasional **geomagnetic reversal** events, in which the magnetic poles effectively swap places.
#
# Aside from all these complications, the magnetic field of the Earth is stable enough for us to use it for navigation. In a compass, a magnetized needle on a low-friction bearing will swivel to align itself with the local magnetic field. This tells us what *direction* the horizontal component of the local field is pointing in, but what of the *magnitude*? Where you stand, how strong is the Earth's magnetic field?
#
# In this pre-lab, you will use simple vector analysis to see how it's possible to measure the local magnetic field using only a compass, a coil of wire, and a DC power source. This will equip you with the analytic tools to carry out the actual experiment in this week's lab.
#
# Together, the power source and the coil form a simple electromagnet called a **solenoid**. In accordance with Ampère's law, the steady current produces a magnetic field. Due to the geometry of the solenoid, the internal field is approximately uniform and points along the axis of the coil (Fig. 2).
#
# Calculating the magnetic field at an arbitrary position near an arbitrary solenoid, while not impossible, is very difficult to do. However, if we're interested in the field at the midpoint of the solenoid's axis, the calculation can be greatly simplified by assuming that the solenoid is *infinitely long*. It can be shown that this approximation holds when the radius of the solenoid is much less than its length.
#
# One obtains the following result for the strength of the magnetic field inside the solenoid and near its midpoint:
#
# \begin{align}
# B = \mu_0 n I
# \label{eq:Bmag} \tag{1}
# \end{align}
#
# where $I$ is the electrical current in the coil, $n$ is the **turn density**, or the number of turns per unit length, and $ \mu_0 = 4\pi \times 10^{-7} $ H/m is a constant, called the **permeability of free space**.
#
# <br>
# <br>
# <p>
# <center>
# <img src="https://cmps-people.ok.ubc.ca/jbobowsk/PHYS_121_Lab/Lab7/images/solenoid.svg" alt="image info" style="width: 45%; height: auto;" /><br>
# <b>Fig. 2: The magnetic field generated by a solenoid. Near the centre of the solenoid, the magnetic field lines essentially parallel to the axis of the solenoid, but begin to bend near the ends.    Figure adapted from <a href = "https://commons.wikimedia.org/wiki/File:VFPt_Solenoid_correct3_Babs.svg">Wikimedia commons</b>.</center>
# </p>

# %% [markdown]
# **<span style="color:blue">Question 1:</span>**
#
# You place a compass in the middle of a solenoid with current $I = 0$. The solenoid is oriented with its axis perpendicular to magnetic north, so that the angle between the compass needle and the axis of the solenoid is $90^\circ$.
#
# You then turn on the power, so that the current flows through the solenoid and produces a magnetic field as shown in Fig. 2. What happens to the needle as you gradually increase the current? Why?

# %% [markdown]
# ***
# **<span style="color:blue">Answer 1:</span>**
#
# [//]: # (Please do not delete this comment or anything above it.  Anything below this comment can be deleted.)
#
# Double click this cell and enter your text here.  When done, hit 'Shift' + 'Enter' to execute the cell.  You may delete this text when entering your answer.
# ***

# %% [markdown]
# **<span style="color:blue">Question 2:</span>**
#
# Let $\vec{B}_\mathrm{Loc}$ be the local magnetic field in the regiod of space occupied by the solenoid. The observed deflection of the compass needle is due to the magnetic field generated by the solenoid $\vec{B}_\mathrm{Sol}$. By the principle of superposition, the *total magnetic field* in the middle of the solenoid is given by
#
# $$ \vec{B}_\mathrm{Tot} = \vec{B}_\mathrm{Loc} + \vec{B}_\mathrm{Sol} $$
#
# <br>
# <p>
# <center>
# <img src="https://cmps-people.ok.ubc.ca/jbobowsk/PHYS_121_Lab/Lab7/images/btot.svg" style="width: 25%" />
# <b>Fig. 3: The total magnetic field is given by superposition of the fixed local field $\vec{B}_\mathrm{Loc}$ and the variable solenoid field $\vec{B}_\mathrm{Sol}$. The direction of this total field (and thus the measured angle $\varphi$) can be changed by varying the current in the solenoid, according to Eq. (1). </b></center>
# </p>
#
# The compass needle will point along $\vec{B}_\mathrm{Tot}$. Noting that these fields are perpendicular to one another, use some simple trigonometric analysis to find an expression relating the angle $\varphi$ from Fig. 3 and the relative magnitudes of the local field and the solenoid field. Solve your expression for $B_\mathrm{Loc}$ = $\left| \vec{B}_\mathrm{Loc} \right|$.
#
# ***
# **<span style="color:blue">Answer 2:</span>**
#
# Using the cell below, type your expression for $B_\mathrm{Loc}$ (denoted B_loc below) in terms of the variables B_sol, and phi.

# %%
# Please do not delete or modify the two lines directly below this comment.  
# They are used to allow the user to enter symbol expressions into this cell.
from sympy import symbols, tan
B_loc, B_sol, phi = symbols('B_loc B_sol phi')

# Enter a symbolic expression for B_loc in terms of B_sol and phi.
B_loc = ...

# %% [markdown]
# ***
# **<span style="color:blue">Question 3:</span>**
#
# If we're thinking like experimentalists, we should be seeking an expression of the quantity of interest (the local magnetic field) in terms of easily measured quantities. The angle $\varphi$ is easy to measure, but it's not obvious how to measure $B_\mathrm{Sol}$.
#
# Use Eq. (1) and your expression from Question 2 to find an expression for $B_\mathrm{Loc}$ in terms of the current.
#
#
# ***
# **<span style="color:blue">Answer 3:</span>**
#
# In the cell below, type a symbolic expression for B_loc in terms of phi, I, n, and u0. Remember that $\mu_0$ just represents a constant equal to $4\pi \times 10^{-7}\rm\ H/m$.

# %%
# Please do not delete or modify the line directly below this comment.  
# It is used to allow the user to enter symbol expressions into this cell.
B_loc, n, I, u0 = symbols('B_loc n I u0')

# Enter a symbolic expression for B_loc in terms of I, n, u0, and phi.
B_loc = ...

# %% [markdown]
# ***
# **<span style="color:blue">Question 4:</span>**
#
# To get a better estimate of $B_\mathrm{Loc}$, we should take a set of measurements of $\varphi$ over a range of currents $I$. Suppose you were to plot $\tan\varphi$ as a function of $I$ -- the result would be a linear set of data as shown in Fig. 4.
#
# <br>
# <p>
# <center>
# <img src="https://cmps-people.ok.ubc.ca/jbobowsk/PHYS_121_Lab/Lab7/images/linearPlot.png" style="width: 50%" />
# <br>
# <b>Fig. 4: An example plot of $\tan\varphi$ as a function of $I$ (using made up data).  The red line represents a linear fint to the data points. </b></center>
# </p>
#
# >  (a)  Find an expression for the slope $m$ of the $\tan\varphi$ versus $I$ plot. You should be able to find your answer by rearranging your expression from Question 3. <br>
#   (b)  Express $B_\mathrm{Loc}$ in terms of the slope $m$.
#
# ***
# **<span style="color:blue">Answer 4:</span>**
#
# In the cell below, enter an expression for B_loc in terms of m, n, and u0.

# %%
# Please do not delete or modify the line directly below this comment.  
# It is used to allow the user to enter symbol expressions into this cell.
m, B_loc, n, u0 = symbols('m B_loc n u0')

# Enter a symbolic expression for B_loc in terms m, n, and u0.
B_loc = ...

# %% [markdown]
# Last update: December 6, 2022
